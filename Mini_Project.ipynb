# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Google

df1 = pd.read_csv('C:/Users/KIIT/Downloads/GOOG.csv')

# %%
df1
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-01-13   91.528000   92.980003   90.930000   92.800003   92.800003
# 1    2023-01-17   92.779999   92.970001   90.839996   92.160004   92.160004
# 2    2023-01-18   92.940002   93.587997   91.400002   91.779999   91.779999
# 3    2023-01-19   91.389999   94.400002   91.379997   93.910004   93.910004
# 4    2023-01-20   95.949997   99.419998   95.910004   99.279999   99.279999
# ..          ...         ...         ...         ...         ...         ...
# 246  2024-01-08  138.000000  140.639999  137.880005  140.529999  140.529999
# 247  2024-01-09  140.059998  142.800003  139.789993  142.559998  142.559998
# 248  2024-01-10  142.520004  144.524994  142.460007  143.800003  143.800003
# 249  2024-01-11  144.895004  146.660004  142.214996  143.669998  143.669998
# 250  2024-01-12  144.339996  144.740005  143.360001  144.240005  144.240005
#
#        Volume
# 0    18630700
# 1    22935800
# ...

# %%
##2.


print(df1.head())


print(df1.isnull().sum())

df1 = df1.dropna()

df1['Date'] = pd.to_datetime(df1['Date'])
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2023-01-13  91.528000  92.980003  90.930000  92.800003  92.800003  18630700
# 1  2023-01-17  92.779999  92.970001  90.839996  92.160004  92.160004  22935800
# 2  2023-01-18  92.940002  93.587997  91.400002  91.779999  91.779999  19641600
# 3  2023-01-19  91.389999  94.400002  91.379997  93.910004  93.910004  28707700
# 4  2023-01-20  95.949997  99.419998  95.910004  99.279999  99.279999  53704800
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
##3.
df1['Daily_Return'] = df1['Close'].pct_change() * 100  


print(df1[['Close', 'Daily_Return']])
# Out:
#           Close  Daily_Return
# 0     92.800003           NaN
# 1     92.160004     -0.689654
# 2     91.779999     -0.412332
# 3     93.910004      2.320773
# 4     99.279999      5.718235
# ..          ...           ...
# 246  140.529999      2.285465
# 247  142.559998      1.444531
# 248  143.800003      0.869813
# 249  143.669998     -0.090407
# 250  144.240005      0.396747
#
# [251 rows x 2 columns]

# %%
df1
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2023-01-13   91.528000   92.980003   90.930000   92.800003   92.800003
# 1   2023-01-17   92.779999   92.970001   90.839996   92.160004   92.160004
# 2   2023-01-18   92.940002   93.587997   91.400002   91.779999   91.779999
# 3   2023-01-19   91.389999   94.400002   91.379997   93.910004   93.910004
# 4   2023-01-20   95.949997   99.419998   95.910004   99.279999   99.279999
# ..         ...         ...         ...         ...         ...         ...
# 246 2024-01-08  138.000000  140.639999  137.880005  140.529999  140.529999
# 247 2024-01-09  140.059998  142.800003  139.789993  142.559998  142.559998
# 248 2024-01-10  142.520004  144.524994  142.460007  143.800003  143.800003
# 249 2024-01-11  144.895004  146.660004  142.214996  143.669998  143.669998
# 250 2024-01-12  144.339996  144.740005  143.360001  144.240005  144.240005
#
#        Volume  Daily_Return
# 0    18630700           NaN
# ...

# %%
###4.
plt.figure(figsize=(12, 6))
plt.plot(df1['Date'], df1['Volume'], label='Volume')
plt.title('Stock Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.show()

# %%
##5.
window_size = 20

df1['SMA_20'] = df1['Close'].rolling(window=window_size).mean()


plt.figure(figsize=(12, 6))
plt.plot(df1['Date'], df1['Close'], label='Close Price')
plt.plot(df1['Date'], df1['SMA_20'], label=f'{window_size}-day SMA', color='orange')
plt.title('Stock Close Price with Moving Average')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
##6.
df1['Daily_Return'] = df1['Close'].pct_change() * 100
average_daily_return = df1['Daily_Return'].mean()
print(f"Average Daily Return: {average_daily_return:.2f}%")
# Out:
# Average Daily Return: 0.19%

# %%
##7

df1['Trend'] = np.where(df1['Daily_Return'] > 0, 'Up', np.where(df1['Daily_Return'] < 0, 'Down', 'No Change'))

# %%
df1
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2023-01-13   91.528000   92.980003   90.930000   92.800003   92.800003
# 1   2023-01-17   92.779999   92.970001   90.839996   92.160004   92.160004
# 2   2023-01-18   92.940002   93.587997   91.400002   91.779999   91.779999
# 3   2023-01-19   91.389999   94.400002   91.379997   93.910004   93.910004
# 4   2023-01-20   95.949997   99.419998   95.910004   99.279999   99.279999
# ..         ...         ...         ...         ...         ...         ...
# 246 2024-01-08  138.000000  140.639999  137.880005  140.529999  140.529999
# 247 2024-01-09  140.059998  142.800003  139.789993  142.559998  142.559998
# 248 2024-01-10  142.520004  144.524994  142.460007  143.800003  143.800003
# 249 2024-01-11  144.895004  146.660004  142.214996  143.669998  143.669998
# 250 2024-01-12  144.339996  144.740005  143.360001  144.240005  144.240005
#
#        Volume  Daily_Return    SMA_20      Trend
# ...

# %%
##8.
import matplotlib.pyplot as plt


trend_counts = df1['Trend'].value_counts()


plt.figure(figsize=(8, 8))
plt.pie(trend_counts, labels=trend_counts.index, autopct='%1.1f%%', startangle=90, colors=['green', 'red', 'gray'])
plt.title('Trend Frequency')
plt.show()

# %%
##Microsoft
df2 = pd.read_csv('C:/Users/KIIT/Downloads/MSFT.csv')

# %%
df2
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-01-13  237.000000  239.369995  234.919998  239.229996  237.127426
# 1    2023-01-17  237.970001  240.910004  237.089996  240.350006  238.237595
# 2    2023-01-18  241.570007  242.380005  235.520004  235.809998  233.737457
# 3    2023-01-19  233.779999  235.520004  230.679993  231.929993  229.891571
# 4    2023-01-20  234.860001  240.740005  234.509995  240.220001  238.108719
# ..          ...         ...         ...         ...         ...         ...
# 246  2024-01-08  369.299988  375.200012  369.010010  374.690002  374.690002
# 247  2024-01-09  372.010010  375.989990  371.190002  375.790009  375.790009
# 248  2024-01-10  376.369995  384.170013  376.320007  382.769989  382.769989
# 249  2024-01-11  386.000000  390.679993  380.380005  384.630005  384.630005
# 250  2024-01-12  385.489990  388.679993  384.649994  388.470001  388.470001
#
#        Volume
# 0    21333300
# 1    29831300
# ...

# %%
##2.
print(df2.head())


print(df2.isnull().sum())

df2 = df2.dropna()

df2['Date'] = pd.to_datetime(df2['Date'])
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-01-13  237.000000  239.369995  234.919998  239.229996  237.127426
# 1 2023-01-17  237.970001  240.910004  237.089996  240.350006  238.237595
# 2 2023-01-18  241.570007  242.380005  235.520004  235.809998  233.737457
# 3 2023-01-19  233.779999  235.520004  230.679993  231.929993  229.891571
# 4 2023-01-20  234.860001  240.740005  234.509995  240.220001  238.108719
#
#      Volume
# 0  21333300
# 1  29831300
# 2  30028700
# 3  28623000
# 4  35389800
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
##3.
df2['Daily_Return'] = df2['Close'].pct_change() * 100  


print(df2[['Close', 'Daily_Return']])
# Out:
#           Close  Daily_Return
# 0    239.229996           NaN
# 1    240.350006      0.468173
# 2    235.809998     -1.888915
# 3    231.929993     -1.645395
# 4    240.220001      3.574358
# ..          ...           ...
# 246  374.690002      1.887152
# 247  375.790009      0.293578
# 248  382.769989      1.857415
# 249  384.630005      0.485936
# 250  388.470001      0.998361
#
# [251 rows x 2 columns]

# %%
df2
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2023-01-13  237.000000  239.369995  234.919998  239.229996  237.127426
# 1   2023-01-17  237.970001  240.910004  237.089996  240.350006  238.237595
# 2   2023-01-18  241.570007  242.380005  235.520004  235.809998  233.737457
# 3   2023-01-19  233.779999  235.520004  230.679993  231.929993  229.891571
# 4   2023-01-20  234.860001  240.740005  234.509995  240.220001  238.108719
# ..         ...         ...         ...         ...         ...         ...
# 246 2024-01-08  369.299988  375.200012  369.010010  374.690002  374.690002
# 247 2024-01-09  372.010010  375.989990  371.190002  375.790009  375.790009
# 248 2024-01-10  376.369995  384.170013  376.320007  382.769989  382.769989
# 249 2024-01-11  386.000000  390.679993  380.380005  384.630005  384.630005
# 250 2024-01-12  385.489990  388.679993  384.649994  388.470001  388.470001
#
#        Volume  Daily_Return
# 0    21333300           NaN
# ...

# %%
##4.
plt.figure(figsize=(12, 6))
plt.plot(df2['Date'], df2['Volume'], label='Volume')
plt.title('Stock Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.show()

# %%
##5.
window_size = 20

df2['SMA_20'] = df2['Close'].rolling(window=window_size).mean()


plt.figure(figsize=(12, 6))
plt.plot(df2['Date'], df2['Close'], label='Close Price')
plt.plot(df2['Date'], df2['SMA_20'], label=f'{window_size}-day SMA', color='orange')
plt.title('Stock Close Price with Moving Average')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
##6.
df2['Daily_Return'] = df2['Close'].pct_change() * 100
average_daily_return = df2['Daily_Return'].mean()
print(f"Average Daily Return: {average_daily_return:.2f}%")
# Out:
# Average Daily Return: 0.21%

# %%
##7.


df2['Trend'] = np.where(df2['Daily_Return'] > 0, 'Up', np.where(df1['Daily_Return'] < 0, 'Down', 'No Change'))

# %%
df2
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2023-01-13  237.000000  239.369995  234.919998  239.229996  237.127426
# 1   2023-01-17  237.970001  240.910004  237.089996  240.350006  238.237595
# 2   2023-01-18  241.570007  242.380005  235.520004  235.809998  233.737457
# 3   2023-01-19  233.779999  235.520004  230.679993  231.929993  229.891571
# 4   2023-01-20  234.860001  240.740005  234.509995  240.220001  238.108719
# ..         ...         ...         ...         ...         ...         ...
# 246 2024-01-08  369.299988  375.200012  369.010010  374.690002  374.690002
# 247 2024-01-09  372.010010  375.989990  371.190002  375.790009  375.790009
# 248 2024-01-10  376.369995  384.170013  376.320007  382.769989  382.769989
# 249 2024-01-11  386.000000  390.679993  380.380005  384.630005  384.630005
# 250 2024-01-12  385.489990  388.679993  384.649994  388.470001  388.470001
#
#        Volume  Daily_Return      SMA_20      Trend
# ...

# %%
##8
import matplotlib.pyplot as plt


trend_counts = df2['Trend'].value_counts()


plt.figure(figsize=(8, 8))
plt.pie(trend_counts, labels=trend_counts.index, autopct='%1.1f%%', startangle=90, colors=['green', 'red', 'gray'])
plt.title('Trend Frequency')
plt.show()

# %%
##Apple
df3 = pd.read_csv('C:/Users/KIIT/Downloads/AAPL.csv')
df3
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-01-13  132.029999  134.919998  131.660004  134.759995  134.010941
# 1    2023-01-17  134.830002  137.289993  134.130005  135.940002  135.184372
# 2    2023-01-18  136.820007  138.610001  135.029999  135.210007  134.458450
# 3    2023-01-19  134.080002  136.250000  133.770004  135.270004  134.518112
# 4    2023-01-20  135.279999  138.020004  134.220001  137.869995  137.103653
# ..          ...         ...         ...         ...         ...         ...
# 246  2024-01-08  182.089996  185.600006  181.500000  185.559998  185.559998
# 247  2024-01-09  183.919998  185.149994  182.729996  185.139999  185.139999
# 248  2024-01-10  184.350006  186.399994  183.919998  186.190002  186.190002
# 249  2024-01-11  186.539993  187.050003  183.619995  185.589996  185.589996
# 250  2024-01-12  186.059998  186.740005  185.190002  185.919998  185.919998
#
#        Volume
# 0    57809700
# 1    63646600
# ...

# %%
##2.

print(df3.head())


print(df3.isnull().sum())

df3 = df3.dropna()

df3['Date'] = pd.to_datetime(df3['Date'])
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-01-13  132.029999  134.919998  131.660004  134.759995  134.010941
# 1 2023-01-17  134.830002  137.289993  134.130005  135.940002  135.184372
# 2 2023-01-18  136.820007  138.610001  135.029999  135.210007  134.458450
# 3 2023-01-19  134.080002  136.250000  133.770004  135.270004  134.518112
# 4 2023-01-20  135.279999  138.020004  134.220001  137.869995  137.103653
#
#      Volume
# 0  57809700
# 1  63646600
# 2  69672800
# 3  58280400
# 4  80223600
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
##3.
df3['Daily_Return'] = df3['Close'].pct_change() * 100  


print(df3[['Close', 'Daily_Return']])
# Out:
#           Close  Daily_Return
# 0    134.759995           NaN
# 1    135.940002      0.875636
# 2    135.210007     -0.536998
# 3    135.270004      0.044373
# 4    137.869995      1.922075
# ..          ...           ...
# 246  185.559998      2.417488
# 247  185.139999     -0.226341
# 248  186.190002      0.567140
# 249  185.589996     -0.322255
# 250  185.919998      0.177812
#
# [251 rows x 2 columns]

# %%
df3
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2023-01-13  132.029999  134.919998  131.660004  134.759995  134.010941
# 1   2023-01-17  134.830002  137.289993  134.130005  135.940002  135.184372
# 2   2023-01-18  136.820007  138.610001  135.029999  135.210007  134.458450
# 3   2023-01-19  134.080002  136.250000  133.770004  135.270004  134.518112
# 4   2023-01-20  135.279999  138.020004  134.220001  137.869995  137.103653
# ..         ...         ...         ...         ...         ...         ...
# 246 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.559998
# 247 2024-01-09  183.919998  185.149994  182.729996  185.139999  185.139999
# 248 2024-01-10  184.350006  186.399994  183.919998  186.190002  186.190002
# 249 2024-01-11  186.539993  187.050003  183.619995  185.589996  185.589996
# 250 2024-01-12  186.059998  186.740005  185.190002  185.919998  185.919998
#
#        Volume  Daily_Return
# 0    57809700           NaN
# ...

# %%
##4.
plt.figure(figsize=(12, 6))
plt.plot(df3['Date'], df3['Volume'], label='Volume')
plt.title('Stock Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.show()

# %%
##5.
window_size = 20

df3['SMA_20'] = df3['Close'].rolling(window=window_size).mean()


plt.figure(figsize=(12, 6))
plt.plot(df3['Date'], df3['Close'], label='Close Price')
plt.plot(df3['Date'], df3['SMA_20'], label=f'{window_size}-day SMA', color='orange')
plt.title('Stock Close Price with Moving Average')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
##6.
df3['Daily_Return'] = df3['Close'].pct_change() * 100
average_daily_return = df3['Daily_Return'].mean()
print(f"Average Daily Return: {average_daily_return:.2f}%")
# Out:
# Average Daily Return: 0.14%

# %%
##7.
df3['Trend'] = np.where(df3['Daily_Return'] > 0, 'Up', np.where(df3['Daily_Return'] < 0, 'Down', 'No Change'))

# %%
df3
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2023-01-13  132.029999  134.919998  131.660004  134.759995  134.010941
# 1   2023-01-17  134.830002  137.289993  134.130005  135.940002  135.184372
# 2   2023-01-18  136.820007  138.610001  135.029999  135.210007  134.458450
# 3   2023-01-19  134.080002  136.250000  133.770004  135.270004  134.518112
# 4   2023-01-20  135.279999  138.020004  134.220001  137.869995  137.103653
# ..         ...         ...         ...         ...         ...         ...
# 246 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.559998
# 247 2024-01-09  183.919998  185.149994  182.729996  185.139999  185.139999
# 248 2024-01-10  184.350006  186.399994  183.919998  186.190002  186.190002
# 249 2024-01-11  186.539993  187.050003  183.619995  185.589996  185.589996
# 250 2024-01-12  186.059998  186.740005  185.190002  185.919998  185.919998
#
#        Volume  Daily_Return      SMA_20      Trend
# ...

# %%
##8
import matplotlib.pyplot as plt


trend_counts = df3['Trend'].value_counts()


plt.figure(figsize=(8, 8))
plt.pie(trend_counts, labels=trend_counts.index, autopct='%1.1f%%', startangle=90, colors=['green', 'red', 'gray'])
plt.title('Trend Frequency')
plt.show()

# %%
##Amazon
df4 = pd.read_csv('C:/Users/KIIT/Downloads/AMZN.csv')

# %%
df4
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-01-13   94.180000   98.370003   94.120003   98.120003   98.120003
# 1    2023-01-17   98.680000   98.889999   95.730003   96.050003   96.050003
# 2    2023-01-18   97.250000   99.320000   95.379997   95.459999   95.459999
# 3    2023-01-19   94.739998   95.440002   92.860001   93.680000   93.680000
# 4    2023-01-20   93.860001   97.349998   93.199997   97.250000   97.250000
# ..          ...         ...         ...         ...         ...         ...
# 246  2024-01-08  146.740005  149.399994  146.149994  149.100006  149.100006
# 247  2024-01-09  148.330002  151.710007  148.210007  151.369995  151.369995
# 248  2024-01-10  152.059998  154.419998  151.880005  153.729996  153.729996
# 249  2024-01-11  155.039993  157.169998  153.119995  155.179993  155.179993
# 250  2024-01-12  155.389999  156.199997  154.009995  154.619995  154.619995
#
#        Volume
# 0    85549400
# 1    72755000
# ...

# %%
##2.
print(df4.head())


print(df4.isnull().sum())

df4 = df4.dropna()

df4['Date'] = pd.to_datetime(df4['Date'])
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2023-01-13  94.180000  98.370003  94.120003  98.120003  98.120003  85549400
# 1  2023-01-17  98.680000  98.889999  95.730003  96.050003  96.050003  72755000
# 2  2023-01-18  97.250000  99.320000  95.379997  95.459999  95.459999  79570400
# 3  2023-01-19  94.739998  95.440002  92.860001  93.680000  93.680000  69002700
# 4  2023-01-20  93.860001  97.349998  93.199997  97.250000  97.250000  67481500
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
##3.
df4['Daily_Return'] = df4['Close'].pct_change() * 100  


print(df4[['Close', 'Daily_Return']])
# Out:
#           Close  Daily_Return
# 0     98.120003           NaN
# 1     96.050003     -2.109662
# 2     95.459999     -0.614268
# 3     93.680000     -1.864654
# 4     97.250000      3.810845
# ..          ...           ...
# 246  149.100006      2.657671
# 247  151.369995      1.522461
# 248  153.729996      1.559094
# 249  155.179993      0.943210
# 250  154.619995     -0.360870
#
# [251 rows x 2 columns]

# %%
df4
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2023-01-13   94.180000   98.370003   94.120003   98.120003   98.120003
# 1   2023-01-17   98.680000   98.889999   95.730003   96.050003   96.050003
# 2   2023-01-18   97.250000   99.320000   95.379997   95.459999   95.459999
# 3   2023-01-19   94.739998   95.440002   92.860001   93.680000   93.680000
# 4   2023-01-20   93.860001   97.349998   93.199997   97.250000   97.250000
# ..         ...         ...         ...         ...         ...         ...
# 246 2024-01-08  146.740005  149.399994  146.149994  149.100006  149.100006
# 247 2024-01-09  148.330002  151.710007  148.210007  151.369995  151.369995
# 248 2024-01-10  152.059998  154.419998  151.880005  153.729996  153.729996
# 249 2024-01-11  155.039993  157.169998  153.119995  155.179993  155.179993
# 250 2024-01-12  155.389999  156.199997  154.009995  154.619995  154.619995
#
#        Volume  Daily_Return
# 0    85549400           NaN
# ...

# %%
##4.
plt.figure(figsize=(12, 6))
plt.plot(df4['Date'], df4['Volume'], label='Volume')
plt.title('Stock Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.show()

# %%
##5.
window_size = 20

df4['SMA_20'] = df4['Close'].rolling(window=window_size).mean()


plt.figure(figsize=(12, 6))
plt.plot(df4['Date'], df4['Close'], label='Close Price')
plt.plot(df4['Date'], df4['SMA_20'], label=f'{window_size}-day SMA', color='orange')
plt.title('Stock Close Price with Moving Average')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
##6.
df4['Daily_Return'] = df4['Close'].pct_change() * 100
average_daily_return = df4['Daily_Return'].mean()
print(f"Average Daily Return: {average_daily_return:.2f}%")
# Out:
# Average Daily Return: 0.20%

# %%
##7
df4['Trend'] = np.where(df4['Daily_Return'] > 0, 'Up', np.where(df3['Daily_Return'] < 0, 'Down', 'No Change'))

# %%
df4
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2023-01-13   94.180000   98.370003   94.120003   98.120003   98.120003
# 1   2023-01-17   98.680000   98.889999   95.730003   96.050003   96.050003
# 2   2023-01-18   97.250000   99.320000   95.379997   95.459999   95.459999
# 3   2023-01-19   94.739998   95.440002   92.860001   93.680000   93.680000
# 4   2023-01-20   93.860001   97.349998   93.199997   97.250000   97.250000
# ..         ...         ...         ...         ...         ...         ...
# 246 2024-01-08  146.740005  149.399994  146.149994  149.100006  149.100006
# 247 2024-01-09  148.330002  151.710007  148.210007  151.369995  151.369995
# 248 2024-01-10  152.059998  154.419998  151.880005  153.729996  153.729996
# 249 2024-01-11  155.039993  157.169998  153.119995  155.179993  155.179993
# 250 2024-01-12  155.389999  156.199997  154.009995  154.619995  154.619995
#
#        Volume  Daily_Return      SMA_20      Trend
# ...

# %%
##8.
import matplotlib.pyplot as plt


trend_counts = df4['Trend'].value_counts()


plt.figure(figsize=(8, 8))
plt.pie(trend_counts, labels=trend_counts.index, autopct='%1.1f%%', startangle=90, colors=['green', 'red', 'gray'])
plt.title('Trend Frequency')
plt.show()

# %%
##correlation between the stocks AAPL,MSFT,GOOGL,AMZN
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df1['Ticker'] = 'AAPL'
df2['Ticker'] = 'MSFT'
df3['Ticker'] = 'GOOGL'
df4['Ticker'] = 'AMZN'


merged_df = pd.concat([df1, df2, df3, df4], ignore_index=True)


pivot_df = merged_df.pivot(index='Date', columns='Ticker', values='Daily_Return')

correlation_matrix = pivot_df.corr()


plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of Daily Returns')
plt.show()
